# %%
import sys
sys.path.append('..')

# %%
import xgi
from utils.xgi_hypergraph_utils import *

# %%
H = xgi.Hypergraph([['v1', 'v2', 'v3'],
                    ['v2', 'v3', 'v5'],
                    ['v3', 'v6', 'v7'],
                    ['v3', 'v5', 'v7', 'v8', 'v9'],
                    ['v4', 'v5']])
xgi.draw(H, node_size=15, node_labels=True, hyperedge_labels=True)
# Out:
# (<Axes: >,
#  (<matplotlib.collections.PathCollection at 0x13f91e5ad90>,
# ...
#   <matplotlib.collections.PatchCollection at 0x13f91cef850>))

# %%
import networkx as nx
line_g = xgi.to_line_graph(H)
nx.draw_networkx(line_g)

# %%
derivate_g = derivative_graph(H)
nx.draw_networkx(derivate_g)

# %%
der_list = derivative_list(H)
print(der_list)
# Out:
# [1.0, 3.0, 30.0, 30.0, 30.0, 30.0, 30.0, 30.0, 1.0, 3.0, 30.0, 30.0, 30.0, 30.0, 30.0, 1.5, 3.0, 1.0, 3.0, 3.0, 30.0, 30.0, 3.0, 2.0, 2.0, 2.0, 1.0, 30.0, 30.0, 30.0, 1.0, 1.0, 30.0, 0.0, 30.0, 30.0]
